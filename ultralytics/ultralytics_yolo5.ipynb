# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabir40/Mask-Detection-Yolov5/blob/main/ultralytics/ultralytics_yolo5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clone Yolov5 repo

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12847, done.
# remote: Total 12847 (delta 0), reused 0 (delta 0), pack-reused 12847
# Receiving objects: 100% (12847/12847), 11.81 MiB | 10.51 MiB/s, done.
# Resolving deltas: 100% (8923/8923), done.

# %% [markdown]
# Install Libraries

# %%
# %cd yolov5
# !pip install -qr requirements.txt
# Out:
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.0 MB/s

# %%
# Import required libraries
import pandas as pd
import numpy as np
import os
import glob
from datetime import datetime
import xml.etree.ElementTree as ET 
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# display detected images
from IPython.display import Image

# %%
pwd
# Out:
# '/content/yolov5'

# %% [markdown]
# import dataset from kagge

# %%
import os
import json

from google.colab import files
files.upload()


f = open('kaggle.json')
data = json.load(f)
os.environ['KAGGLE_USERNAME'] = data["username"] # username from the json file
os.environ['KAGGLE_KEY'] = data["key"] # key from the json file
# Out:
#      <input type="file" id="files-5b5cbd5f-81f6-4f24-8bc4-faf349729676" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b5cbd5f-81f6-4f24-8bc4-faf349729676">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json 
# !kaggle datasets download -d andrewmvd/face-mask-detection
# Out:
# ...
#  95% 376M/398M [00:01<00:00, 250MB/s]
# 100% 398M/398M [00:01<00:00, 239MB/s]

# %%
import shutil

filename = "face-mask-detection.zip"

extract_dir = "/content/yolov5/face-mask-detection"

shutil.unpack_archive(filename, extract_dir)

# %% [markdown]
# download model

# %%
# !wget https://raw.githubusercontent.com/Cabir40/Mask-Detection-Yolov5/main/ultralytics/best.pt
# Out:
# --2022-04-17 15:36:12--  https://raw.githubusercontent.com/Cabir40/Mask-Detection-Yolov5/main/ultralytics/best.pt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14472773 (14M) [application/octet-stream]
# Saving to: ‘best.pt’
#
# best.pt             100%[===================>]  13.80M  --.-KB/s    in 0.1s
#
# 2022-04-17 15:36:13 (127 MB/s) - ‘best.pt’ saved [14472773/14472773]

# %% [markdown]
# Mertrics

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Test Model

# %%
# !python detect.py --source "face-mask-detection/images/maksssksksss0.png" --weight 'best.pt' --name expTestImage --conf 0.4
# Out:
# ...
# detect: weights=['best.pt'], source=face-mask-detection/images/maksssksksss0.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/face-mask-detection/images/maksssksksss0.png: 480x640 1 with_mask, 2 without_masks, Done. (0.296s)
# Speed: 3.0ms pre-process, 296.3ms inference, 14.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage

# %%
Image("runs/detect/expTestImage/maksssksksss0.png")

# %%
# !python detect.py --source "face-mask-detection/images/maksssksksss2.png" --weight 'best.pt' --name expTestImage --conf 0.4
# Out:
# detect: weights=['best.pt'], source=face-mask-detection/images/maksssksksss2.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/face-mask-detection/images/maksssksksss2.png: 480x640 3 with_masks, 1 mask_weared_incorrect, Done. (0.295s)
# Speed: 2.6ms pre-process, 294.9ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage5

# %%
Image("runs/detect/expTestImage5/maksssksksss2.png")

# %%
# !python detect.py --source "face-mask-detection/images/maksssksksss530.png" --weight 'best.pt' --name expTestImage --conf 0.4
# Out:
# detect: weights=['best.pt'], source=face-mask-detection/images/maksssksksss530.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/face-mask-detection/images/maksssksksss530.png: 640x512 1 without_mask, Done. (0.333s)
# Speed: 3.2ms pre-process, 333.4ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage4

# %%
Image("runs/detect/expTestImage4/maksssksksss530.png")

# %% [markdown]
# External image

# %%
# !wget https://www.ed.ac.uk/files/styles/landscape_breakpoints_theme_uoe_mobile_1x/public/thumbnails/image/gettyimages-1215069129_jacoblund.png
# Out:
# --2022-04-17 15:41:13--  https://www.ed.ac.uk/files/styles/landscape_breakpoints_theme_uoe_mobile_1x/public/thumbnails/image/gettyimages-1215069129_jacoblund.png
# Resolving www.ed.ac.uk (www.ed.ac.uk)... 23.185.0.1, 2620:12a:8001::1, 2620:12a:8000::1
# Connecting to www.ed.ac.uk (www.ed.ac.uk)|23.185.0.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628123 (613K) [image/png]
# Saving to: ‘gettyimages-1215069129_jacoblund.png’
#
# gettyimages-1215069 100%[===================>] 613.40K  --.-KB/s    in 0.04s
#
# 2022-04-17 15:41:13 (14.4 MB/s) - ‘gettyimages-1215069129_jacoblund.png’ saved [628123/628123]

# %%
# !python detect.py --source "gettyimages-1215069129_jacoblund.png" --weights 'best.pt' --name expTestImage --conf 0.4
# Out:
# detect: weights=['best.pt'], source=gettyimages-1215069129_jacoblund.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/gettyimages-1215069129_jacoblund.png: 448x640 3 with_masks, 4 without_masks, Done. (0.275s)
# Speed: 2.9ms pre-process, 275.0ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage6

# %%
Image("runs/detect/expTestImage6/gettyimages-1215069129_jacoblund.png")

# %%
# !wget https://raw.githubusercontent.com/Cabir40/Mask-Detection-Yolov5/main/ultralytics/wrong_masks.png
# Out:
# --2022-04-17 15:46:46--  https://raw.githubusercontent.com/Cabir40/Mask-Detection-Yolov5/main/ultralytics/wrong_masks.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1271695 (1.2M) [image/png]
# Saving to: ‘wrong_masks.png’
#
# wrong_masks.png     100%[===================>]   1.21M  --.-KB/s    in 0.05s
#
# 2022-04-17 15:46:46 (23.2 MB/s) - ‘wrong_masks.png’ saved [1271695/1271695]

# %%
# !python detect.py --source "wrong_masks.png" --weights 'best.pt' --name expTestImage --conf 0.4
# Out:
# detect: weights=['best.pt'], source=wrong_masks.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/wrong_masks.png: 640x640 2 with_masks, 2 without_masks, 1 mask_weared_incorrect, Done. (0.405s)
# Speed: 3.9ms pre-process, 405.3ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage7

# %%
Image("runs/detect/expTestImage7/wrong_masks.png")
