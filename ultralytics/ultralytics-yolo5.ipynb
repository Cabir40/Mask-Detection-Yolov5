# %% [markdown]
# Clone Yolov5 repo

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12847, done.
# remote: Total 12847 (delta 0), reused 0 (delta 0), pack-reused 12847
# Receiving objects: 100% (12847/12847), 11.82 MiB | 14.48 MiB/s, done.
# Resolving deltas: 100% (8929/8929), done.

# %% [markdown]
# Install Libraries

# %%
# %cd yolov5
# !pip install -qr requirements.txt
# Out:
# /content/yolov5
#      |████████████████████████████████| 596 kB 7.9 MB/s

# %%
# Import required libraries
import pandas as pd
import numpy as np
import os
import glob
from datetime import datetime
import xml.etree.ElementTree as ET 
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# display detected images
from IPython.display import Image

# %%
pwd
# Out:
# '/content/yolov5'

# %% [markdown]
# import dataset from kagge

# %%
import os
import json

from google.colab import files
files.upload()


f = open('kaggle.json')
data = json.load(f)
os.environ['KAGGLE_USERNAME'] = data["username"] # username from the json file
os.environ['KAGGLE_KEY'] = data["key"] # key from the json file
# Out:
#      <input type="file" id="files-90fb8d16-1e13-4afd-86a6-3c5014653607" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90fb8d16-1e13-4afd-86a6-3c5014653607">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json 
# !kaggle datasets download -d andrewmvd/face-mask-detection
# Out:
# ...
#  95% 379M/398M [00:02<00:00, 190MB/s]
# 100% 398M/398M [00:02<00:00, 168MB/s]

# %%
import shutil

filename = "face-mask-detection.zip"

extract_dir = "/content/yolov5/face-mask-detection"

shutil.unpack_archive(filename, extract_dir)

# %% [markdown]
# download model

# %% [markdown]
# Test Model

# %%
# !python detect.py --source "face-mask-detection/images/maksssksksss0.png" --weight 'best2.pt' --name expTestImage --conf 0.4
# Out:
# detect: weights=['best2.pt'], source=face-mask-detection/images/maksssksksss0.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/face-mask-detection/images/maksssksksss0.png: 480x640 2 with_masks, Done. (0.324s)
# Speed: 6.0ms pre-process, 323.9ms inference, 14.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage3

# %%
Image("runs/detect/expTestImage3/maksssksksss0.png")

# %%
# !python detect.py --source "face-mask-detection/images/maksssksksss1.png" --weight 'best2.pt' --name expTestImage --conf 0.4
# Out:
# detect: weights=['best2.pt'], source=face-mask-detection/images/maksssksksss1.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/face-mask-detection/images/maksssksksss1.png: 256x640 10 with_masks, Done. (0.171s)
# Speed: 2.7ms pre-process, 171.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage4

# %%
Image("runs/detect/expTestImage4/maksssksksss1.png")

# %%
# !python detect.py --source "face-mask-detection/images/maksssksksss530.png" --weight 'best2.pt' --name expTestImage --conf 0.4
# Out:
# detect: weights=['best2.pt'], source=face-mask-detection/images/maksssksksss530.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=expTestImage, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/face-mask-detection/images/maksssksksss530.png: 640x512 1 with_mask, Done. (0.368s)
# Speed: 4.9ms pre-process, 367.8ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/expTestImage5

# %%
Image("runs/detect/expTestImage5/maksssksksss530.png")
